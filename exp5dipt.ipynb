# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
image1=cv2.imread("mountains.png")
image2=cv2.cvtColor(image1,cv2.COLOR_BGR2RGB)
kernel=np.ones((11,11),np.float32)/169
image3=cv2.filter2D(image2,-1,kernel)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[3], line 2
#       1 image1=cv2.imread("mountains.jpg")
# ----> 2 image2=cv2.cvtColor(image1,cv2.COLOR_BGR2RGB)
#       3 kernel=np.ones((11,11),np.float32)/169
#       4 image3=cv2.filter2D(image2,-1,kernel)
#
# error: OpenCV(4.13.0) D:\bld\libopencv_1776479497034\work\modules\imgproc\src\color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'

# %%
plt.figure(figsize=(9,9))
plt.subplot(1,2,1)
plt.imshow(image2)
plt.title("Original Image")
plt.axis("off")
plt.subplot(1,2,2)
plt.imshow(image3)
plt.title("Average Filter Image")
plt.axis("off")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 3
#       1 plt.figure(figsize=(9,9))
#       2 plt.subplot(1,2,1)
# ----> 3 plt.imshow(image2)
#       4 plt.title("Original Image")
#       5 plt.axis("off")
#
# NameError: name 'image2' is not defined
